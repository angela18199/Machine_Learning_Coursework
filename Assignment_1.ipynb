# %% [markdown]
# # Assignment 1 - Probability, Linear Algebra, Programming, and Git

# %% [markdown]
# ## *Tzu-Chun Hsieh*
# Netid: th264

# %% [markdown]
# Instructions for all assignments can be found [here](https://github.com/kylebradbury/ids705/blob/master/assignments/_Assignment%20Instructions.ipynb), which is also linked to from the [course syllabus](https://kylebradbury.github.io/ids705/index.html).

# %% [markdown]
# # Probability and Statistics Theory

# %% [markdown]
# *Note: for all assignments, write out all equations and math using markdown and [LaTeX](https://tobi.oetiker.ch/lshort/lshort.pdf). For this assignment show ALL math work*

# %% [markdown]
# ## 1
# **[3 points]**
# Let $f(x) = \begin{cases}
#                 0           & x < 0  \\
#                 \alpha x^2  & 0 \leq x \leq 2 \\
#                 0           & 2 < x
#             \end{cases}$
#
# For what value of $\alpha$ is $f(x)$ a valid probability density function?

# %% [markdown]
# **ANSWER**
# $\int_0^{2} \alpha x^2dx = 1\qquad \\
# \Rightarrow \frac{1}{3}\alpha x^3\vert^2_0 = 1 \\
# \Rightarrow \frac{1}{3}\alpha * 2^3 = 1\\
# \Rightarrow \alpha = \frac{3}{8}
# $

# %% [markdown]
# ## 2
# **[3 points]** What is the cumulative distribution function (CDF) that corresponds to the following probability distribution function? Please state the value of the CDF for all possible values of $x$.
#
# $f(x) = \begin{cases}
#     \frac{1}{3} & 0 < x < 3 \\
#     0           & \text{otherwise}
#     \end{cases}$

# %% [markdown]
# **ANSWER**
# CDF function $F(x) = \begin{cases}
#                 0           & x \leq 0  \\
#                 \int_0^{x}\frac{1}{3}dx\qquad          & 0 < x < 3 \\
#                 0           & x\geq 3
#             \end{cases}$

# %% [markdown]
# ## 3
# **[6 points]** For the probability distribution function for the random variable $X$,
#
# $f(x) = \begin{cases}
#     \frac{1}{3} & 0 < x < 3 \\
#     0           & \text{otherwise}
#     \end{cases}$
#
# what is the (a) expected value and (b) variance of $X$. *Show all work*.

# %% [markdown]
# **ANSWER**
# (a)
# $E[X] = \int_0^{3} xf(x)dx = \int_0^{3} \frac{1}{3}xdx =  \frac{1}{6}x^2\vert^3_0 = \frac{9}{6} = \frac{3}{2} \qquad \\
# $
#
# (b)
# $Var[X] = E[X^2] - E[X]^2 \\
# \qquad\>\>\>\> = \int_0^{3}x^2f(x)dx - (\frac{3}{2})^2 \\
# \qquad\>\>\>\> = \int_0^{3}\frac{1}{3}x^2dx - (\frac{3}{2})^2 \\
# \qquad\>\>\>\> = \frac{1}{9}x^3\vert^3_0 - (\frac{3}{2})^2 \\
# \qquad\>\>\>\> = 3 - \frac{9}{4} \\
# \qquad\>\>\>\> = \frac{3}{4}
# $

# %% [markdown]
# ## 4
# **[6 points]** Consider the following table of data that provides the values of a discrete data vector $\mathbf{x}$ of samples from the random variable $X$, where each entry in $\mathbf{x}$ is given as $x_i$.
#
# *Table 1. Dataset N=5 observations*
#
# |        | $x_0$ | $x_1$ | $x_2$ | $x_3$ | $x_4$ |
# |------  |-------|-------|-------|-------|-------|
# |$\textbf{x}$| 2     | 3     | 10    | -1    | -1    |
#
# What is the (a) mean, (b) variance, and the  of the data?
#
# *Show all work. Your answer should include the definition of mean, median, and variance in the context of discrete data.*

# %% [markdown]
# **ANSWER**
# $(a) mean = \frac{2+3+10-1-1}{5} = \frac{13}{5} = 2.6\\
# (b) variance = \frac{\sum_{i = 0}^4(x_i - \frac{13}{5})^2}{5} \\
# \qquad \qquad \>= \frac{1}{5}[(2-\frac{13}{5})^2 + (3-\frac{13}{5})^2 + (10-\frac{13}{5})^2 + 2*(-1-\frac{13}{5})^2] \\
# \qquad \qquad \>= 16.24
# $

# %% [markdown]
# ## 5
# **[8 points]** Review of counting from probability theory.
#
# (a) How many different 7-place license plates are possible if the first 3 places only contain letters and the last 4 only contain numbers?
#
# (b) How many different batting orders are possible for a baseball team with 9 players?
#
# (c) How many batting orders of 5 players are possible for a team with 9 players total?
#
# (d) Let's assume this class has 26 students and we want to form project teams. How many unique teams of 3 are possible?
#
# *Hint: For each problem, determine if order matters, and if it should be calculated with or without replacement.*

# %% [markdown]
# **ANSWER**
# (a) The order matters and should be calculated with replacement.
# $26^3 * 10^4 = 17576000$
#
# (b) The order matters and should be calculated without replacement.
# $9! = 362880$
#
# (c) The order matters and should be calculated without replacement.
# $C^9_5 * 5! = 15120$
#
# (d) The order does not matter and should be calculated without replacement.
# $C^{26}_3 = 2600$

# %% [markdown]
# # Linear Algebra

# %% [markdown]
# ## 6
# **[7 points]** **Matrix manipulations and multiplication**. Machine learning involves working with many matrices, so this exercise will provide you with the opportunity to practice those skills.
#
# Let
# $\mathbf{A} =  \begin{bmatrix}
# 1 & 2 & 3 \\
# 2 & 4 & 5 \\
# 3 & 5 & 6
# \end{bmatrix}$, $\mathbf{b} =  \begin{bmatrix}
# -1  \\
# 3  \\
# 8
# \end{bmatrix}$, $\mathbf{c} =  \begin{bmatrix}
# 4  \\
# -3  \\
# 6
# \end{bmatrix}$, and $\mathbf{I} =  \begin{bmatrix}
# 1 & 0 & 0 \\
# 0 & 1 & 0 \\
# 0 & 0 & 1
# \end{bmatrix}$
#
# Compute the following or indicate that it cannot be computed:
#
# 1. $\mathbf{A}\mathbf{A}$
# 2. $\mathbf{A}\mathbf{A}^T$
# 3. $\mathbf{A}\mathbf{b}$
# 4. $\mathbf{A}\mathbf{b}^T$
# 5. $\mathbf{b}\mathbf{A}$
# 6. $\mathbf{b}^T\mathbf{A}$
# 7. $\mathbf{b}\mathbf{b}$
# 8. $\mathbf{b}^T\mathbf{b}$
# 9. $\mathbf{b}\mathbf{b}^T$
# 10. $\mathbf{b} + \mathbf{c}^T$
# 11. $\mathbf{b}^T\mathbf{b}^T$
# 12. $\mathbf{A}^{-1}\mathbf{b}$
# 13. $\mathbf{A}\circ\mathbf{A}$
# 14. $\mathbf{b}\circ\mathbf{c}$
#
# *Note: The element-wise (or Hadamard) product is the product of each element in one matrix with the corresponding element in another matrix, and is represented by the symbol "$\circ$".*

# %% [markdown]
# **ANSWER**
# 4, 5, 7, 10 and 11 cannot be computed.

# %%
import numpy as np
A = np.array([[1,2,3],[2,4,5],[3,5,6]])
b = np.array([[-1],[3],[8]])
c = np.array([[4],[-3],[6]]) 
print('1:')
print(np.dot(A,A))
print('2:')
print(np.dot(A,np.transpose(A)))
print('3:')
print(np.dot(A,b))
print('6:')
print(np.dot(np.transpose(b),A))
print('8:')
print(np.dot(np.transpose(b), b))
print('9:')
print(np.dot(b, np.transpose(b)))
print('12:')
print(np.dot(np.linalg.inv(A),b))
print('13:')
print(np.multiply(A,A))
print('14:')
print(np.multiply(b,c))
# Out:
# 1:
# [[14 25 31]
#  [25 45 56]
#  [31 56 70]]
# 2:
# [[14 25 31]
#  [25 45 56]
#  [31 56 70]]
# 3:
# [[29]
#  [50]
#  [60]]
# 6:
# [[29 50 60]]
# 8:
# [[74]]
# 9:
# [[ 1 -3 -8]
#  [-3  9 24]
#  [-8 24 64]]
# 12:
# [[ 6.]
#  [ 4.]
#  [-5.]]
# 13:
# [[ 1  4  9]
#  [ 4 16 25]
#  [ 9 25 36]]
# 14:
# [[-4]
#  [-9]
#  [48]]

# %% [markdown]
# ## 7
# **[8 points]** **Eigenvectors and eigenvalues**. Eigenvectors and eigenvalues are useful for some machine learning algorithms, but the concepts take time to solidly grasp. For an intuitive review of these concepts, explore this [interactive website at Setosa.io](http://setosa.io/ev/eigenvectors-and-eigenvalues/). Also, the series of linear algebra videos by Grant Sanderson of 3Brown1Blue are excellent and can be viewed on youtube [here](https://www.youtube.com/playlist?list=PLZHQObOWTQDPD3MizzM2xVFitgF8hE_ab).
#
# 1. Calculate the eigenvalues and corresponding eigenvectors of matrix $\mathbf{A}$ above, from the last question.
# 2. Choose one of the eigenvector/eigenvalue pairs, $\mathbf{v}$ and $\lambda$, and show that $\mathbf{A} \mathbf{v} = \lambda \mathbf{v}$. Also show that this relationship extends to higher orders: $\mathbf{A} \mathbf{A} \mathbf{v} = \lambda^2 \mathbf{v}$
# 3. Show that the eigenvectors are orthogonal to one another (e.g. their inner product is zero). This is true for real, symmetric matrices.

# %% [markdown]
# **ANSWER**

# %%
w, v = np.linalg.eig(A)
print('1:')
print("eigenvalues:", w)
print("and their corresponding eigenvectors:\n", v)
# Out:
# 1:
# eigenvalues: [11.34481428 -0.51572947  0.17091519]
# and their corresponding eigenvectors:
#  [[-0.32798528 -0.73697623  0.59100905]
#  [-0.59100905 -0.32798528 -0.73697623]
#  [-0.73697623  0.59100905  0.32798528]]

# %%
print('2:')
print('Av=𝜆𝐯')
print('𝜆𝐯 = ', np.multiply(w[0],v[:,0]))
# Out:
# 2:
# Av=𝜆𝐯
# 𝜆𝐯 =  [-3.72093206 -6.70488789 -8.36085845]

# %% [markdown]
# $AAv=𝜆^2𝐯$

# %%
print('AAv = ', np.dot(np.dot(A,A), v[:,0]))
print('𝜆𝜆𝐯 = ', np.multiply(np.multiply(w[0], w[0]), v[:,0]))
# Out:
# AAv =  [-42.2132832  -76.06570795 -94.85238636]
# 𝜆𝜆𝐯 =  [-42.2132832  -76.06570795 -94.85238636]

# %%
print('3:')
print('eigenvector 0 is orthogonal to eigenvector 1 since np.dot(v[:,0],v[:1]) is ', format(np.dot(v[:,0],v[:,1]), '.5f'))
print('eigenvector 1 is orthogonal to eigenvector 2 since np.dot(v[:,1],v[:2]) is ', format(np.dot(v[:,1],v[:,2]), '.5f'))
print('eigenvector 0 is orthogonal to eigenvector 2 since np.dot(v[:,0],v[:2]) is ', format(np.dot(v[:,0],v[:,2]), '.5f'))
# Out:
# 3:
# eigenvector 0 is orthogonal to eigenvector 1 since np.dot(v[:,0],v[:1]) is  -0.00000
# eigenvector 1 is orthogonal to eigenvector 2 since np.dot(v[:,1],v[:2]) is  -0.00000
# eigenvector 0 is orthogonal to eigenvector 2 since np.dot(v[:,0],v[:2]) is  -0.00000

# %% [markdown]
# # Numerical Programming

# %% [markdown]
# ## 8
# **[10 points]** Loading data and gathering insights from a real dataset
#
# **Data**. The data for this problem can be found in the `data` subfolder in the `assignments` folder on [github](https://github.com/kylebradbury/ids705). The filename is `egrid2016.xlsx`. This dataset is the Environmental Protection Agency's (EPA) [Emissions & Generation Resource Integrated Database (eGRID)](https://www.epa.gov/energy/emissions-generation-resource-integrated-database-egrid) containing information about all power plants in the United States, the amount of generation they produce, what fuel they use, the location of the plant, and many more quantities. We'll be using a subset of those data.
#
# The fields we'll be using include:
#
# |field    |description|
# |:-----   |:-----|
# |SEQPLT16 |eGRID2016 Plant file sequence number (the index)|
# |PSTATABB |Plant state abbreviation|
# |PNAME    |Plant name |
# |LAT      |Plant latitude |
# |LON      |Plant longitude|
# |PLPRMFL  |Plant primary fuel |
# |CAPFAC   |Plant capacity factor |
# |NAMEPCAP |Plant nameplate capacity (Megawatts MW)|
# |PLNGENAN |Plant annual net generation (Megawatt-hours MWh)|
# |PLCO2EQA |Plant annual CO2 equivalent emissions (tons)|
#
# For more details on the data, you can refer to the [eGrid technical documents](https://www.epa.gov/sites/production/files/2018-02/documents/egrid2016_technicalsupportdocument_0.pdf). For example, you may want to review page 45 and the section "Plant Primary Fuel (PLPRMFL)", which gives the full names of the fuel types including WND for wind, NG for natural gas, BIT for Bituminous coal, etc.
#
# There also are a couple of "gotchas" to watch out for with this dataset:
# - The headers are on the second row and you'll want to ignore the first row (they're more detailed descriptions of the headers).
# - NaN values represent blanks in the data. These will appear regularly in real-world data, so getting experience working with it will be important.
#
# **Your objective**. For this dataset, your goal is answer the following questions about electricity generation in the United States:
#
# **(a)** Which plant has generated the most energy (measured in MWh)?
#
# **(b)** What is the name of the northern-most power plant in the United States?
#
# **(c)** What is the state where the northern-most power plant in the United States is located?
#
# **(d)** Plot a bar plot showing the amount of energy produced by each fuel for the plant.
#
# **(e)** From the plot in (d), which fuel for generation produces the most energy (MWh) in the United States?

# %% [markdown]
# **ANSWER**

# %%
#one plant may have multiple energy generation sites
import pandas as pd
df = pd.read_excel('egrid2016.xlsx', header = 1)

# %%
plant_energy = df.groupby(['PSTATABB','PNAME']).sum() #9701 rows
plant_energy.loc[plant_energy['PLNGENAN'] == plant_energy['PLNGENAN'].max()]
print('(a) Palo Verde in AZ generated the most energy. ')
# Out:
# (a) Palo Verde in AZ generated the most energy.

# %%
df.loc[df['LAT'] == df['LAT'].max()]
print('(b) Barrow.')
print('(c) AK.')
# Out:
# (b) Barrow.
# (c) AK.

# %%
import matplotlib.pyplot as plt
fuel = df.groupby(['PLPRMFL']).sum()['PLNGENAN'].reset_index()
plt.barh(fuel['PLPRMFL'], fuel['PLNGENAN'], align='center', alpha=0.5)
print('(d)')
# Out:
# (d)

# %%
print(fuel.loc[fuel['PLNGENAN']== fuel['PLNGENAN'].max()])
print('(e) NG produces the most energy in United States.')
# Out:
#    PLPRMFL      PLNGENAN
# 13      NG  1.314956e+09
# (e) NG produces the most energy in United States.

# %% [markdown]
# ## 9
# **[8 points]** Speed comparison between vectorized and non-vectorized code. Begin by creating an array of 10 million random numbers using the numpy random.randn module. Compute the sum of the squares first in a for loop, then using Numpy's `dot` module. Time how long it takes to compute each and report the results and report the output. How many times faster is the vectorized code than the for loop approach?
#
# *Note: all code should be well commented, properly formatted, and your answers should be output using the `print()` function as follows (where the # represents your answers, to a reasonable precision):
#
# `Time [sec] (non-vectorized): ######`
#
# `Time [sec] (vectorized):     ######`
#
# `The vectorized code is ##### times faster than the vectorized code`

# %% [markdown]
# **ANSWER**

# %%
import time
array = np.random.randn(10000000)

# %%
non_vectorized = time.time()
sumup = 0
for i in array:
    sumup += i**2
non_elapsed_time = time.time() - non_vectorized
print('Time [sec] (non-vectorized):', non_elapsed_time)

vectorized = time.time()
array.dot(array)
elapsed_time = time.time() - vectorized
print('Time [sec] (vectorized):', elapsed_time)
print('The vectorized code is', non_elapsed_time / elapsed_time, 'times faster than the vectorized code')
# Out:
# Time [sec] (non-vectorized): 5.451658010482788
# Time [sec] (vectorized): 0.004148244857788086
# The vectorized code is 1314.2083453072016 times faster than the vectorized code

# %% [markdown]
# ## 10
# **[10 points]** One popular Agile development framework is Scrum (a paradigm recommended for data science projects). It emphasizes the continual evolution of code for projects, becoming progressively better, but starting with a quickly developed minimum viable product. This often means that code written early on is not optimized, and that's a good thing - it's best to get it to work first before optimizing. Imagine that you wrote the following code during a sprint towards getting an end-to-end system working. Vectorize the following code and show the difference in speed between the current implementation and a vectorized version.
#
# The function below computes the function $f(x,y) = x^2 - 2 y^2$ and determines whether this quantity is above or below a given threshold, `thresh=0`. This is done for $x,y \in \{-4,4\}$, over a 2,000-by-2,000 grid covering that domain.
#
# (a) Vectorize this code and demonstrate (as in the last exercise) the speed increase through vectorization and (b) plot the resulting data - both the function $f(x,y)$ and the thresholded output - using [`imshow`](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.imshow.html?highlight=matplotlib%20pyplot%20imshow#matplotlib.pyplot.imshow) from `matplotlib`.
#
# *Hint: look at the `numpy` [`meshgrid`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.meshgrid.html) documentation*

# %% [markdown]
# **ANSWER**

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

nvalues = 2000
xvalues = np.linspace(-4,4,nvalues)
yvalues = np.linspace(-4,4,nvalues)
thresh  = 0

# Nonvectorized implementation
t0 = time.time()
f = np.zeros((nvalues,nvalues))
f_thresholded = np.zeros((nvalues,nvalues))
for ix, x in enumerate(xvalues):
    for iy, y in enumerate(yvalues):
        f[ix,iy]             = x**2 - 2 * y**2
        f_thresholded[ix,iy] = f[ix,iy] > thresh
t1 = time.time()
time_nonvectorized = t1 - t0

# Vectorized implementation
t0_v = time.time()
X,Y = np.meshgrid(xvalues, yvalues)
f_vec = np.multiply(X,X) - 2*np.multiply(Y,Y)
f_thresholded_vec = f_vec > thresh

t1_v = time.time()
time_vectorized = t1_v - t0_v

# Vectorization speed performance results
print('(a)')
print('The speed of nonvectorized implementation:',time_nonvectorized)
print('The speed of vectorized implementation:',time_vectorized)
print('The speed increase through vectorization:', time_nonvectorized - time_vectorized)

# Plot the function f(x,y)
print('\n(b)')
print('function 𝑓(𝑥,𝑦):')
plt.imshow(f_vec)
plt.show()
print('The thresholded output:')
plt.imshow(f_thresholded_vec)
plt.show()
# Out:
# (a)
# The speed of nonvectorized implementation: 7.520773887634277
# The speed of vectorized implementation: 0.05137801170349121
# The speed increase through vectorization: 7.469395875930786
#
# (b)
# function 𝑓(𝑥,𝑦):
# The thresholded output:

# %% [markdown]
# ## 11
# **[10 points]** This exercise will walk through some basic numerical programming exercises.
# 1. Synthesize $n=10^4$ normally distributed data points with mean $\mu=2$ and a standard deviation of $\sigma=1$. Call these observations from a random variable $X$, and call the vector of observations that you generate, $\textbf{x}$.
# 2. Calculate the mean and standard deviation of $\textbf{x}$ to validate (1) and provide the result to a precision of four significant figures.
# 3. Plot a histogram of the data in $\textbf{x}$ with 30 bins
# 4. What is the 90th percentile of $\textbf{x}$? The 90th percentile is the value below which 90% of observations can be found.
# 5. What is the 99th percentile of $\textbf{x}$?
# 6. Now synthesize $n=10^4$ normally distributed data points with mean $\mu=0$ and a standard deviation of $\sigma=3$. Call these observations from a random variable $Y$, and call the vector of observations that you generate, $\textbf{y}$.
# 7. Create a new figure and plot the histogram of the data in $\textbf{y}$ on the same axes with the histogram of $\textbf{x}$, so that both histograms can be seen and compared.
# 8. Using the observations from $\textbf{x}$ and $\textbf{y}$, estimate $E[XY]$

# %% [markdown]
# **ANSWER**

# %%
x = np.random.normal(2, 1, 10000)
print('Mean:', x.mean())
print('Standard deviation:', x.std())
plt.hist(x, bins =30)
# Out:
# Mean: 2.021407323094786
# Standard deviation: 1.0061018298842097
# (array([1.000e+00, 1.000e+00, 6.000e+00, 9.000e+00, 1.900e+01, 4.100e+01,
#         8.400e+01, 1.340e+02, 2.130e+02, 3.440e+02, 5.000e+02, 6.370e+02,
#         7.820e+02, 8.980e+02, 1.001e+03, 1.013e+03, 9.760e+02, 8.660e+02,
#         7.470e+02, 5.820e+02, 4.210e+02, 2.940e+02, 1.970e+02, 9.300e+01,
#         6.300e+01, 3.800e+01, 2.300e+01, 8.000e+00, 5.000e+00, 4.000e+00]),
#  array([-1.93232916, -1.67446839, -1.41660762, -1.15874685, -0.90088608,
#         -0.64302531, -0.38516455, -0.12730378,  0.13055699,  0.38841776,
#          0.64627853,  0.9041393 ,  1.16200007,  1.41986084,  1.67772161,
#          1.93558238,  2.19344315,  2.45130391,  2.70916468,  2.96702545,
#          3.22488622,  3.48274699,  3.74060776,  3.99846853,  4.2563293 ,
#          4.51419007,  4.77205084,  5.02991161,  5.28777237,  5.54563314,
#          5.80349391]),
#  <a list of 30 Patch objects>)

# %%
print('90th percentile of x:',np.percentile(x, 90))
print('99th percentile of x:',np.percentile(x, 99))

y = np.random.normal(0, 3, 10000)
print('Histogram for x and y:')
plt.hist(x, bins =30, range = (-10, 10), alpha = 0.5)
plt.hist(y, bins =30, color = 'orange', range = (-10, 10), alpha = 0.5)
plt.show()
# Out:
# 90th percentile of x: 3.3016567295631143
# 99th percentile of x: 4.415110888631594
# Histogram for x and y:

# %%
x_co, y_co = np.meshgrid(x, y)
e_xy = np.multiply(x_co, y_co).mean()
print('E[XY]:', e_xy)
# Out:
# E[XY]: 0.036463718831699375

# %% [markdown]
# # Version Control via Git

# %% [markdown]
# ## 12
# **[1 point]** You will need to use Git to submit assignments and in the course projects and is generally a version control and collaboration tool. You can even use some Git repositories (e.g. Github) as hosts for website, such as with the [course website](https://kylebradbury.github.io/ids705/index.html).
#
# Complete the [Atlassian Git tutorial](https://www.atlassian.com/git/tutorials/what-is-version-control), specifically the following listed sections. Try each concept that's presented. For this tutorial, instead of using BitBucket as your remote repository host, you may use your preferred platform such as [Github](https://github.com/) or [Duke's Gitlab](https://gitlab.oit.duke.edu/users/sign_in).
# 1. [What is version control](https://www.atlassian.com/git/tutorials/what-is-version-control)
# 2. [What is Git](https://www.atlassian.com/git/tutorials/what-is-git)
# 3. [Install Git](https://www.atlassian.com/git/tutorials/install-git)
# 4. [Setting up a repository](https://www.atlassian.com/git/tutorials/install-git)
# 5. [Saving changes](https://www.atlassian.com/git/tutorials/saving-changes)
# 6. [Inspecting a repository](https://www.atlassian.com/git/tutorials/inspecting-a-repository)
# 7. [Undoing changes](https://www.atlassian.com/git/tutorials/undoing-changes)
# 8. [Rewriting history](https://www.atlassian.com/git/tutorials/rewriting-history)
# 9. [Syncing](https://www.atlassian.com/git/tutorials/syncing)
# 10. [Making a pull request](https://www.atlassian.com/git/tutorials/making-a-pull-request)
# 11. [Using branches](https://www.atlassian.com/git/tutorials/using-branches)
# 12. [Comparing workflows](https://www.atlassian.com/git/tutorials/comparing-workflows)
#
# I also have created two videos on the topic to help you understand some of these concepts: [Git basics](https://www.youtube.com/watch?v=fBCwfoBr2ng) and a [step-by-step tutorial](https://www.youtube.com/watch?v=nH7qJHx-h5s).
#
# For your answer, affirm that you *either* completed the tutorial or have previous experience with all of the concepts above. Do this by typing your name below and selecting the situation that applies from the two options in brackets.

# %% [markdown]
# **ANSWER**
#
# *I, Tzu-Chun Hsieh, affirm that I have previous experience that covers all the content in this tutorial.*

# %% [markdown]
# # Exploratory Data Analysis
# ## 13
# **[20 points]** Here you'll bring together some of the individual skills that you demonstrated above and create a Jupyter notebook based blog post on data analysis.
#
# 1. Find a dataset that interests you and relates to a question or problem that you find intriguing
# 2. Using a Jupyter notebook, describe the dataset, the source of the data, and the reason the dataset was of interest.
# 3. Check the data and see if they need to be cleaned: are there missing values? Are there clearly erroneous values? Do two tables need to be merged together? Clean the data so it can be visualized.
# 3. Plot the data, demonstrating interesting features that you discover. Are there any relationships between variables that were surprising or patterns that emerged? Please exercise creativity and curiosity in your plots.
# 4. What insights are you able to take away from exploring the data? Is there a reason why analyzing the dataset you chose is particularly interesting or important? Summarize this as if your target audience was the readership of a major news organization - boil down your findings in a way that is accessible, but still accurate.
#
# Here your analysis will evaluated based on:
# 1. Data cleaning: did you look for and work to resolve issues in the data?
# 2. Quality of data exploration: did you provide plots demonstrating interesting aspects of the data?
# 3. Interpretation: Did you clearly explain your insights? Restating the data, alone, is not interpretation.
# 5. Professionalism: Was this work done in a way that exhibits professionalism through clarity, organization, high quality figures and plots, and meaningful descriptions?

# %% [markdown]
# **ANSWER**

# %% [markdown]
# # Tastes of Physical Console Gaming Analysis
# ### Introduction
# Generally, thanks to the widespread electronic devices, at present, video games can be reached through many kinds of devices such as game consoles, computers, smartphone and so on. Among all people who have ever played video games, people who play video games on game consoles are always treated as a gamer. At a very early age, my cousin taught me how to play video games on game consoles. As a result, even I haven't been addicted to playing games, it has been the nature for me to watch out the release of any games. For the past 20 years, it seems that famous game series are accepted by global gamers regardless there may be some cultural differences of interpretation behind the scenes. This might indicate that most of the gamers have the same taste of games. However, after I came to America, I found that there are some games I never heard about but are famous here. Therefore, in this analysis, I am going to use the game sales data to figure out whether gamers in different areas have different tastes of games.
#
# ### Data
# The dataset used in this analysis is obtained from Kaggle (kaggle.com/sidtwr/videogames-sales-dataset), which is originally scraped from Metacritic[1]. Each row in the dataset represents a game on a specific platform. There are 16 columns that record the information related to the games- platform, genre, publisher, developer, sales by area, critic and user score and counts from Metacritic, ESRB rating[2]. The whole dataset has 16719 observations. After taking an initial look at the dataset, I can confirm that there are no weird values for each column. However, it is obvious that there are many NAs. Especially for Critic_Score, Critic_Count, User_Score, User_Count, Developer, and Rating, all these columns have thousands of NAs. As a result, this analysis will not include these columns. Moreover, though the dataset includes the data from 1980 to 2020, this analysis will focus on analyzing the most recent data from 2012 to 2016 since there is only one or no observation for 2017 to 2020. After cleaning the data, there are 14120 observations in the dataset.
#
#
# [1] The website that aggregates reviews of games, TV shows, music albums, and films. "https://www.metacritic.com/".
# [2] The rating assigned by the Entertainment Software Rating Board, a self-regulatory organization. It gives the information that the game content is suitable for people at what age. "https://www.esrb.org/".

# %%
# read and check the dataset
from plotnine import *
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/yu/Documents/Duke/courses/20spring/IDS705 ML/HW/assingment1/Video_Games_Sales_as_at_22_Dec_2016.csv')

# %%
# data cleaning
# Released year: 2011~2016
df_recent = df.loc[(df['Year_of_Release'] > 2011) & (df['Year_of_Release'] < 2017)]

#drop the colums that we are not going to use.
df_recent = df_recent.drop(['Critic_Score','Critic_Count','User_Score','User_Count','Developer','Rating'], axis = 1)

#drop the observation that the Name is NA
#find the index of the two rows
df_recent.loc[df_recent['Name'].isna()]

#drop the observations that the value of Year_of_Release is NA.
df_recent = df_recent.loc[df_recent['Year_of_Release'].notna()]

#drop the observations that the value of publisher is NA because there are only 2 of the rows
df_recent = df_recent.loc[df_recent['Publisher'].notna()]

#df_recent.isna().sum()

# %% [markdown]
# ### EDA & Insights

# %%
#EDA
import warnings; warnings.simplefilter('ignore')
#by genre
global_sale_genre = df_recent.groupby(['Genre']).sum().reset_index(inplace = False).loc[:,['Genre','Global_Sales']].sort_values(by = ['Global_Sales'], ascending = False)
plt.pie(global_sale_genre['Global_Sales'], labels = global_sale_genre['Genre'], autopct='%1.0f%%', shadow=True, startangle=140, radius =2);

# %% [markdown]
# The pie graph above shows the share of global sales for different genres of video games. Action is the most popular genre globally.

# %%
#by genre by area
global_sale_genre_area = df_recent.groupby(['Genre']).sum().reset_index(inplace = False).loc[:,['Genre','Global_Sales','NA_Sales','EU_Sales','JP_Sales','Other_Sales']].sort_values(by = ['Global_Sales'], ascending = False).reset_index(inplace = False).drop(['index'], axis =1)

global_sale_genre_area['NA_Sales_%'] = global_sale_genre_area['NA_Sales'] / global_sale_genre_area['NA_Sales'].sum()
global_sale_genre_area['EU_Sales_%'] = global_sale_genre_area['EU_Sales'] / global_sale_genre_area['EU_Sales'].sum()
global_sale_genre_area['JP_Sales_%'] = global_sale_genre_area['JP_Sales'] / global_sale_genre_area['JP_Sales'].sum()
global_sale_genre_area['Other_Sales_%'] = global_sale_genre_area['Other_Sales'] / global_sale_genre_area['Other_Sales'].sum()

# transfer the table to the format to plot
global_sale_genre_area = pd.melt(global_sale_genre_area, id_vars='Genre', value_vars=['Global_Sales', 'NA_Sales','EU_Sales','JP_Sales','Other_Sales','NA_Sales_%','EU_Sales_%','JP_Sales_%','Other_Sales_%'])
global_sale_genre_area = global_sale_genre_area.rename(columns={"variable": "Sale_type"})

(ggplot(global_sale_genre_area.loc[60:,['Genre','Sale_type','value']], aes(x = 'Sale_type', y= 'value', fill = 'Genre')) + geom_col() + ylab('share'))
# Out:
# <ggplot: (305703821)>

# %% [markdown]
# The pie graph above shows the share of global sales for different genres of video games. Action is the most popular genre globally. However, if we see the share of the genre of games by area, we can see a diverse trend for different areas. The stack bar plot above shows the share of the genre of games by area. Action games still earn big shares in each area. However, apparently, the most popular genre in Japan is role-playing games. Moreover, comparing to other areas, shooter games are much less popular in Japan. These indicate that Japanese gamers have a distinct taste of games. Therefore, any company that wants to earn market share on the Japanese market should release role-playing games or change the way of advertising their non-role-playing games to attract Japanese gamers.

# %%
#by publisher
global_sale_publisher = df_recent.groupby(['Publisher']).sum().reset_index(inplace = False).loc[:,['Publisher','Global_Sales']].sort_values(by = ['Global_Sales'], ascending = False).reset_index()
global_sale_publisher.loc[10:, 'Publisher'] = 'Others'
global_sale_publisher = global_sale_publisher.groupby(['Publisher']).sum().reset_index(inplace = False).loc[:,['Publisher','Global_Sales']].sort_values(by = ['Global_Sales'], ascending = False).reset_index()
plt.pie(global_sale_publisher['Global_Sales'], labels = global_sale_publisher['Publisher'], autopct='%1.0f%%', shadow=True, startangle=140, radius =2);

# %% [markdown]
# Now, I use a different aspect to see the taste of gamers. The pie graph above shows the share of global sales for different publishers of video games. Obviously, Electronic Arts is the most popular publisher globally, followed by Nintendo and Activision.

# %%
#by publisher by area
global_sale_pub_area = df_recent.groupby(['Publisher']).sum().reset_index(inplace = False).loc[:,['Publisher','Global_Sales','NA_Sales','EU_Sales','JP_Sales','Other_Sales']].sort_values(by = ['Global_Sales'], ascending = False).reset_index().drop(['index'], axis =1)
global_sale_pub_area.loc[10:, 'Publisher'] = 'Others'
global_sale_pub_area = global_sale_pub_area.groupby(['Publisher']).sum().reset_index(inplace = False).loc[:,['Publisher','Global_Sales', 'NA_Sales','EU_Sales','JP_Sales','Other_Sales']].sort_values(by = ['Global_Sales'], ascending = False).reset_index().drop(['index'], axis =1)
global_sale_pub_area['NA_Sales_%'] = global_sale_pub_area['NA_Sales'] / global_sale_pub_area['NA_Sales'].sum()
global_sale_pub_area['EU_Sales_%'] = global_sale_pub_area['EU_Sales'] / global_sale_pub_area['EU_Sales'].sum()
global_sale_pub_area['JP_Sales_%'] = global_sale_pub_area['JP_Sales'] / global_sale_pub_area['JP_Sales'].sum()
global_sale_pub_area['Other_Sales_%'] = global_sale_pub_area['Other_Sales'] / global_sale_pub_area['Other_Sales'].sum()

# transfer the table to the format to plot
global_sale_pub_area = pd.melt(global_sale_pub_area, id_vars='Publisher', value_vars=['Global_Sales', 'NA_Sales','EU_Sales','JP_Sales','Other_Sales','NA_Sales_%','EU_Sales_%','JP_Sales_%','Other_Sales_%'])
global_sale_pub_area = global_sale_pub_area.rename(columns={"variable": "Sale_type"})

(ggplot(global_sale_pub_area.loc[55:,['Publisher','Sale_type','value']], aes(x = 'Sale_type', y= 'value', fill = 'Publisher')) + geom_col() + ylab('share'))
# Out:
# <ggplot: (305065441)>

# %% [markdown]
# However, if we see the share of publishers of games by area, we can see a diverse trend for different areas. The bar plot above shows the share of publishers of games by area. Again, the Japanese market shows the unique taste of publishers. Different from other markets that favor games published by Electronic Arts and Activision, Japanese gamers like to play games published by Nintendo and Namco Bandai Games. Moreover, the share of the games released by other small publishers is almost 40%. These indicate that Japanese gamers favor the games created by their own country and small game companies. Therefore, it is hard for companies outside of Japan to compete in the market.

# %% [markdown]
# ### Summary
# In this analysis, I tried to use the game sales data to figure out whether gamers in different areas have different tastes of games. It turns out that Japanese gamers have distinct tastes toward games. This reflects the share of sales for genres and publishers. They like role-playing games the most and play games published by companies from their country. Japanese physical console gaming market is unique. Companies that want to earn a market share in this market would need a different marketing strategy to approach.
